# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("D:\Data Science\Python Notes\Data-files-master\Real estate.csv")
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
data.drop(['No'] , axis =1 , inplace = True)

# %%
data
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
data.isnull().sum()
# Out:
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   X1 transaction date                     414 non-null    float64
#  1   X2 house age                            414 non-null    float64
#  2   X3 distance to the nearest MRT station  414 non-null    float64
#  3   X4 number of convenience stores         414 non-null    int64
#  4   X5 latitude                             414 non-null    float64
#  5   X6 longitude                            414 non-null    float64
#  6   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 22.8 KB

# %%
data.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148971     17.712560
# std               0.281967     11.392485
# min            2012.667000      0.000000
# 25%            2012.917000      9.025000
# 50%            2013.167000     16.100000
# 75%            2013.417000     28.150000
# max            2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# ...

# %%
data1 = data.rename({'X5 latitude' : 'latitude'} , axis = 1 , inplace = True)
data2 = data.rename({'X6 longitude' : 'longitude'} , axis  = 1 , inplace = True)
data3 = data.rename({'X1 transaction date' : 'date'} , axis  = 1 , inplace = True)
data4 = data.rename({'X3 distance to the nearest MRT station' : 'near_station'} , axis  = 1 , inplace = True)
data5 = data.rename({'X4 number of convenience stores' : 'stores'} , axis  = 1 , inplace = True)
data6 = data.rename({'X2 house age' : 'age'} , axis  = 1 , inplace = True)

# %%
cor = data.corr()

# %%
sns.heatmap(data = cor , annot = True)
plt.show()

# %%
data.columns
# Out:
# Index(['date', 'age', 'near_station', 'stores', 'latitude', 'longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
data
# Out:
#          date   age  near_station  stores  latitude  longitude  \
# 0    2012.917  32.0      84.87882      10  24.98298  121.54024
# 1    2012.917  19.5     306.59470       9  24.98034  121.53951
# 2    2013.583  13.3     561.98450       5  24.98746  121.54391
# 3    2013.500  13.3     561.98450       5  24.98746  121.54391
# 4    2012.833   5.0     390.56840       5  24.97937  121.54245
# ..        ...   ...           ...     ...       ...        ...
# 409  2013.000  13.7    4082.01500       0  24.94155  121.50381
# 410  2012.667   5.6      90.45606       9  24.97433  121.54310
# 411  2013.250  18.8     390.96960       7  24.97923  121.53986
# 412  2013.000   8.1     104.81010       5  24.96674  121.54067
# 413  2013.500   6.5      90.45606       9  24.97433  121.54310
#
#      Y house price of unit area
# 0                          37.9
# 1                          42.2
# 2                          47.3
# 3                          54.8
# 4                          43.1
# ...

# %%
x = data.drop(['Y house price of unit area'] , axis = 1)
y = data['Y house price of unit area']

# %%
x
# Out:
#          date   age  near_station  stores  latitude  longitude
# 0    2012.917  32.0      84.87882      10  24.98298  121.54024
# 1    2012.917  19.5     306.59470       9  24.98034  121.53951
# 2    2013.583  13.3     561.98450       5  24.98746  121.54391
# 3    2013.500  13.3     561.98450       5  24.98746  121.54391
# 4    2012.833   5.0     390.56840       5  24.97937  121.54245
# ..        ...   ...           ...     ...       ...        ...
# 409  2013.000  13.7    4082.01500       0  24.94155  121.50381
# 410  2012.667   5.6      90.45606       9  24.97433  121.54310
# 411  2013.250  18.8     390.96960       7  24.97923  121.53986
# 412  2013.000   8.1     104.81010       5  24.96674  121.54067
# 413  2013.500   6.5      90.45606       9  24.97433  121.54310
#
# [414 rows x 6 columns]

# %%
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
from sklearn.model_selection import train_test_split
Xtrain , Xtest , Ytrain , Ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(Xtrain , Ytrain)
# Out:
# LinearRegression()

# %%
Ypred = lr.predict(Xtest)

# %%
from sklearn.metrics import r2_score

r2_score(Ytest , Ypred)
# Out:
# 0.6810580555095943

# %%
import gradio as gr
data.columns
# Out:
# Index(['date', 'age', 'near_station', 'stores', 'latitude', 'longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
def price(age,date, near_station, stores, latitude, longitude):

    x = np.array([age,date, near_station, stores, latitude, longitude])
    pred = lr.predict(x)

    return pred

# %%
output = gr.outputs.Textbox()

app = gr.Interface(fn = price , inputs = ['number','number','number','number','number','number'] , outputs=output)

# %%
app.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7866
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "D:\Softwares\Anaconda Python\lib\site-packages\gradio\routes.py", line 393, in run_predict
#     output = await app.get_blocks().process_api(
#   File "D:\Softwares\Anaconda Python\lib\site-packages\gradio\blocks.py", line 1108, in process_api
#     result = await self.call_function(
#   File "D:\Softwares\Anaconda Python\lib\site-packages\gradio\blocks.py", line 915, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "D:\Softwares\Anaconda Python\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
# ...
